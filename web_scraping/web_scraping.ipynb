# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
import time
import re
import datetime

# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежими новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: `<дата> - <заголовок> - <ссылка>`

# %%
KEYWORDS = ['python', 'парсинг']
URL_HABR_NEWS = 'https://habr.com/ru/news/'
MAX_PAGE = 50  # Последняя страница всегда 50-ая

# %%
def check_keywords_in_text(text, keywords):
    text_words = re.split('\s', text.lower())
    for word in keywords:
        if word in text_words:
            return True
    return False

# %%
def get_habr_news():
    list_news = []
    for i in range(1, MAX_PAGE+1):
        print(f'Страница: {i}')
        time.sleep(1)
        date = datetime.datetime.now().date()
        res = requests.get(f'{URL_HABR_NEWS}page{i}')
        soup = BeautifulSoup(res.text, 'html.parser')
        soap_articles = soup.find_all('article', class_='post post_preview')
        
        for articles in soap_articles:
            news = {}
            news['request_dt'] = date
            news['article_dt'] = articles.find('span', class_='post__time').text
            news['article_header'] = articles.find('h2').text
            news['article_preview'] = articles.find('div', class_='post__text').text
            news['article_ref'] = articles.find('h2').find('a').get('href')
        
            list_news.append(news)
    
    return list_news

# %%
def filter_habr_news_by_keywords(news, keywords):
    filter_news = []
    for article in news:
        text_header = article['article_header']
        text_preview = article['article_preview']
        text_content = article.get('content', '')

        if check_keywords_in_text(text_header, keywords) or \
            check_keywords_in_text(text_preview, keywords) or \
            check_keywords_in_text(text_content, keywords):
            filter_news.append(article)
    return filter_news

# %%
def transformation_date_article(article_dt, request_dt):
    months = {'января':'Jan',
         'февраля':'Feb',
         'марта':'Mar',
         'апреля':'Apr',
         'мая':'May',
         'июня':'Jun',
         'июля':'Jul',
         'августа':'Aug',
         'сентября':'Sep',
         'октября':'Oct',
         'ноября':'Nov',
         'декабря':'Dec'}
    
    if 'сегодня' in article_dt:
        dt = request_dt.strftime('%Y-%m-%d')
    
    elif 'вчера' in article_dt:
        dt = (request_dt - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    
    else:
        dt_list = article_dt.split(' ')[:3]
        dt = datetime.datetime.strptime(dt_list[0] + ' ' 
                                        + months[f'{dt_list[1]}'] + ' ' 
                                        + dt_list[2], '%d %b %Y').strftime('%Y-%m-%d')
    
    return dt

# %%
news = get_habr_news()
# Out:
# Страница: 1
# Страница: 2
# Страница: 3
# Страница: 4
# Страница: 5
# Страница: 6
# Страница: 7
# Страница: 8
# Страница: 9
# Страница: 10
# Страница: 11
# Страница: 12
# Страница: 13
# Страница: 14
# Страница: 15
# Страница: 16
# Страница: 17
# Страница: 18
# Страница: 19
# Страница: 20
# Страница: 21
# Страница: 22
# Страница: 23
# Страница: 24
# Страница: 25
# Страница: 26
# Страница: 27
# Страница: 28
# Страница: 29
# Страница: 30
# Страница: 31
# Страница: 32
# Страница: 33
# Страница: 34
# Страница: 35
# Страница: 36
# Страница: 37
# Страница: 38
# Страница: 39
# Страница: 40
# Страница: 41
# Страница: 42
# Страница: 43
# Страница: 44
# Страница: 45
# Страница: 46
# Страница: 47
# Страница: 48
# Страница: 49
# Страница: 50

# %%
filter_news = filter_habr_news_by_keywords(news, KEYWORDS)
for article in filter_news:
    article['article_dt_trans'] = transformation_date_article(article['article_dt'], article['request_dt'])

# %%
df = pd.DataFrame(filter_news, columns=['article_dt_trans', 'request_dt', 'article_dt', 'article_header', 'article_preview', 'article_ref'])
df.drop(['request_dt', 'article_preview', 'article_dt'], axis=1)
# Out:
#   article_dt_trans                                     article_header  \
# 0       2021-02-01  \nMail.ru Group открывает набор на бесплатные ...
# 1       2020-12-14  \nГлубокое обучение на Kotlin: вышла альфа-вер...
#
#                                          article_ref
# 0  https://habr.com/ru/company/mailru/news/t/540268/
# 1  https://habr.com/ru/company/JetBrains/news/t/5...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: `<дата> - <заголовок> - <ссылка> - <текст_статьи>`

# %%
def get_habr_news_full_text(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    return soup.find('div', class_='post__text').text

# %%
news_full = [] 
for article in news:
    print(article['article_ref'])
    article_full = {}
    while True:
        try:
            time.sleep(1)
            article_full['request_dt'] = article['request_dt']
            article_full['article_dt'] = article['article_dt']
            article_full['article_header'] = article['article_header']
            article_full['article_preview'] = article['article_preview']
            article_full['article_ref'] = article['article_ref']
            article_full['content'] = get_habr_news_full_text(article['article_ref'])
            break
        except Exception as er:
            print(er)
    news_full.append(article_full)
# Out:
# https://habr.com/ru/news/t/542342/
# https://habr.com/ru/news/t/542332/
# https://habr.com/ru/news/t/542320/
# https://habr.com/ru/news/t/542318/
# https://habr.com/ru/news/t/542310/
# https://habr.com/ru/news/t/542306/
# https://habr.com/ru/news/t/542268/
# https://habr.com/ru/news/t/542240/
# https://habr.com/ru/news/t/542230/
# https://habr.com/ru/news/t/542236/
# https://habr.com/ru/news/t/542232/
# https://habr.com/ru/news/t/542228/
# https://habr.com/ru/news/t/542222/
# https://habr.com/ru/news/t/542186/
# https://habr.com/ru/news/t/542164/
# https://habr.com/ru/news/t/542146/
# https://habr.com/ru/news/t/542124/
# https://habr.com/ru/news/t/542112/
# https://habr.com/ru/news/t/542100/
# https://habr.com/ru/news/t/542092/
# https://habr.com/ru/news/t/542072/
# https://habr.com/ru/news/t/542060/
# https://habr.com/ru/news/t/542054/
# https://habr.com/ru/company/parallels/news/t/534010/
# https://habr.com/ru/news/t/534002/
# https://habr.com/ru/news/t/533988/
# https://habr.com/ru/news/t/533994/
# https://habr.com/ru/news/t/533986/
# https://habr.com/ru/news/t/533982/
# https://habr.com/ru/news/t/533938/
# https://habr.com/ru/news/t/533930/
# https://habr.com/ru/news/t/533908/
# https://habr.com/ru/news/t/533898/
# https://habr.com/ru/news/t/533896/
# https://habr.com/ru/news/t/533894/
# https://habr.com/ru/news/t/533886/
# https://habr.com/ru/news/t/533858/
# https://habr.com/ru/news/t/533826/
# https://habr.com/ru/company/sberbank/news/t/533816/
# https://habr.com/ru/news/t/533800/
# https://habr.com/ru/news/t/533792/
# https://habr.com/ru/news/t/533784/
# https://habr.com/ru/news/t/533782/
# https://habr.com/ru/news/t/533766/
# https://habr.com/ru/news/t/533744/
# https://habr.com/ru/news/t/533742/
# https://habr.com/ru/news/t/533722/
# https://habr.com/ru/news/t/533708/
# https://habr.com/ru/news/t/533700/
# https://habr.com/ru/news/t/533698/
# https://habr.com/ru/news/t/533688/
# https://habr.com/ru/news/t/533684/
# https://habr.com/ru/news/t/533674/
# https://habr.com/ru/news/t/533648/
# https://habr.com/ru/news/t/533658/
# https://habr.com/ru/news/t/533646/
# https://habr.com/ru/news/t/533644/
# https://habr.com/ru/news/t/533616/
# https://habr.com/ru/news/t/533592/
# https://habr.com/ru/news/t/533590/
# https://habr.com/ru/news/t/533576/
# https://habr.com/ru/news/t/533488/
# https://habr.com/ru/news/t/533568/
# https://habr.com/ru/news/t/533564/
# https://habr.com/ru/news/t/533542/
# https://habr.com/ru/news/t/533528/
# https://habr.com/ru/news/t/533520/
# https://habr.com/ru/news/t/533518/
# https://habr.com/ru/news/t/533502/
# https://habr.com/ru/news/t/533490/
# https://habr.com/ru/news/t/533484/
# https://habr.com/ru/news/t/533472/
# https://habr.com/ru/news/t/533426/
# https://habr.com/ru/news/t/533452/
# https://habr.com/ru/news/t/533446/
# https://habr.com/ru/news/t/533424/
# https://habr.com/ru/company/habr_career/news/t/533408/
# https://habr.com/ru/news/t/533410/
# https://habr.com/ru/news/t/533404/
# https://habr.com/ru/news/t/533392/
# https://habr.com/ru/news/t/533342/
# https://habr.com/ru/news/t/533374/
# https://habr.com/ru/news/t/533352/
# https://habr.com/ru/news/t/533338/
# https://habr.com/ru/news/t/533324/
# https://habr.com/ru/news/t/533310/
# https://habr.com/ru/news/t/533306/
# https://habr.com/ru/news/t/533292/
# https://habr.com/ru/news/t/533284/
# https://habr.com/ru/company/southbridge/news/t/533282/
# https://habr.com/ru/news/t/533262/
# https://habr.com/ru/news/t/533258/
# https://habr.com/ru/news/t/533246/
# https://habr.com/ru/company/southbridge/news/t/533192/
# https://habr.com/ru/news/t/533238/
# https://habr.com/ru/news/t/533224/
# https://habr.com/ru/news/t/533222/
# https://habr.com/ru/news/t/533220/
# https://habr.com/ru/news/t/533202/
# ('Connection aborted.', OSError(0, 'Error'))
# ('Connection aborted.', OSError(0, 'Error'))
# ('Connection aborted.', OSError(0, 'Error'))
# https://habr.com/ru/news/t/533190/
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ('Connection aborted.', OSError(0, 'Error'))
# ('Connection aborted.', OSError(0, 'Error'))
# ('Connection aborted.', OSError(0, 'Error'))
# ('Connection aborted.', OSError(0, 'Error'))
# HTTPSConnectionPool(host='habr.com', port=443): Max retries exceeded with url: /ru/news/t/533190/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001993CBD3D88>: Failed to establish a new connection: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение'))
# HTTPSConnectionPool(host='habr.com', port=443): Max retries exceeded with url: /ru/news/t/533190/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001993F185B48>: Failed to establish a new connection: [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера'))
# HTTPSConnectionPool(host='habr.com', port=443): Max retries exceeded with url: /ru/news/t/533190/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001993F16C808>: Failed to establish a new connection: [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера'))
# HTTPSConnectionPool(host='habr.com', port=443): Max retries exceeded with url: /ru/news/t/533190/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001993F192B48>: Failed to establish a new connection: [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера'))
# HTTPSConnectionPool(host='habr.com', port=443): Max retries exceeded with url: /ru/news/t/533190/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001993F170548>: Failed to establish a new connection: [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера'))
# HTTPSConnectionPool(host='habr.com', port=443): Max retries exceeded with url: /ru/news/t/533190/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001993F192748>: Failed to establish a new connection: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение'))
# https://habr.com/ru/news/t/533188/
# https://habr.com/ru/news/t/533172/
# https://habr.com/ru/company/dcmiran/news/t/533178/
# https://habr.com/ru/company/intersect/news/t/533168/
# https://habr.com/ru/news/t/533164/
# https://habr.com/ru/company/itsumma/news/t/533158/
# https://habr.com/ru/news/t/533152/
# https://habr.com/ru/news/t/533148/
# https://habr.com/ru/news/t/533136/
# https://habr.com/ru/news/t/533130/
# https://habr.com/ru/news/t/533000/
# https://habr.com/ru/news/t/533116/
# https://habr.com/ru/news/t/533094/
# https://habr.com/ru/news/t/533050/
# https://habr.com/ru/news/t/533048/
# https://habr.com/ru/company/it-guild/news/t/533026/
# https://habr.com/ru/news/t/533004/
# https://habr.com/ru/company/JetBrains/news/t/532990/
# https://habr.com/ru/news/t/532986/
# https://habr.com/ru/news/t/532970/
# https://habr.com/ru/company/mailru/news/t/532958/
# https://habr.com/ru/news/t/532968/
# https://habr.com/ru/news/t/532948/
# https://habr.com/ru/news/t/532956/
# https://habr.com/ru/news/t/532638/
# https://habr.com/ru/company/mailru/news/t/532108/
# https://habr.com/ru/company/gitlab/news/t/532190/
# https://habr.com/ru/news/t/532174/
# https://habr.com/ru/news/t/532166/
# https://habr.com/ru/news/t/532162/
# https://habr.com/ru/company/yandex_praktikum/news/t/532142/
# https://habr.com/ru/news/t/532144/
# https://habr.com/ru/news/t/532124/
# https://habr.com/ru/news/t/532120/
# https://habr.com/ru/news/t/532102/
# https://habr.com/ru/news/t/532096/
# https://habr.com/ru/news/t/532082/
# https://habr.com/ru/news/t/532074/
# https://habr.com/ru/company/itsumma/news/t/532076/
# https://habr.com/ru/news/t/532064/
# https://habr.com/ru/news/t/532060/
# https://habr.com/ru/news/t/532048/
# https://habr.com/ru/news/t/532034/
# https://habr.com/ru/news/t/532020/
# https://habr.com/ru/news/t/532008/
# https://habr.com/ru/news/t/531978/
# https://habr.com/ru/news/t/531974/
# https://habr.com/ru/news/t/531946/
# https://habr.com/ru/news/t/531960/
# https://habr.com/ru/news/t/531948/
# https://habr.com/ru/news/t/531938/
# https://habr.com/ru/news/t/531924/

# %%
filter_news = filter_habr_news_by_keywords(news_full, KEYWORDS)
for article in filter_news:
    article['article_dt_trans'] = transformation_date_article(article['article_dt'], article['request_dt'])

# %%
df = pd.DataFrame(filter_news, columns=['article_dt_trans', 'request_dt', 'article_dt', 'article_header', 'article_preview', 'article_ref', 'content'])
df.drop(['request_dt', 'article_preview', 'article_dt'], axis=1)
# Out:
#   article_dt_trans                                     article_header  \
# 0       2021-02-10  \nИсследователь взломал системы 35 крупных IT-...
# 1       2021-02-01  \nMail.ru Group открывает набор на бесплатные ...
# 2       2021-02-01  \nMozilla закрывает проекты Firefox Voice и Vo...
# 3       2021-01-25  \nОткрываем четыре Школы: разработки интерфейс...
# 4       2020-12-17  \nВ МТИ показали, как мозг читает компьютерный...
# 5       2020-12-14  \nГлубокое обучение на Kotlin: вышла альфа-вер...
#
#                                          article_ref  \
# 0                 https://habr.com/ru/news/t/541784/
# 1  https://habr.com/ru/company/mailru/news/t/540268/
# 2  https://habr.com/ru/company/itsumma/news/t/540...
# 3  https://habr.com/ru/company/yandex/news/t/538798/
# 4                 https://habr.com/ru/news/t/533518/
# 5  https://habr.com/ru/company/JetBrains/news/t/5...
#
#                                              content
# 0  Исследователю Алексу Бирсану удалось взломать ...
# 1  Мы запускаем два бесплатных онлайн-курса: по с...
# 2  Компания Mozilla объявила о закрытии своих сер...
# 3  В 2012 году трое руководителей разработки, вкл...
# 4  \n\r\nНейробиологи из Массачусетского технолог...
# 5  Всем привет! \nНа днях мы выпустили первую аль...

# %% [markdown]
# ## Задание 2

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: `<почта> - <дата утечки> - <источник утечки> - <описание утечки>`
#
# **Подсказка**: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
EMAIL = ['matlserg@mail.ru', 'matlserg@gmail.com', 'matlserg@yandex.ru']

# %%
url = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'

headers = {
    'Vaar-Version':'0',
    'Vaar-Header-App-Product':'hackcheck-web-avast'
}

payload = {'emailAddresses':EMAIL}

res = requests.post(url, json=payload, headers=headers)
data = res.json()

# %%
desc_breaches = []
for email, breaches in data['summary'].items():
    for breach_id in breaches['breaches']:
        breach = {}
        breach['email'] = email
        breach['Id'] = breach_id
        
        desc_breaches.append(breach)

for breach in desc_breaches:
    desc = data['breaches'][f'{breach["Id"]}']
    breach['source'] = desc['site']
    breach['date'] = datetime.datetime.strptime(desc['publishDate'], "%Y-%m-%dT%H:%M:%SZ").\
                                                                                strftime('%Y-%m-%d')
    breach['desc'] = desc['description']

# %%
df = pd.DataFrame(desc_breaches, columns=['email', 'date', 'source', 'desc'])
df
# Out:
#               email        date            source  \
# 0  matlserg@mail.ru  2019-03-28  verifications.io
# 1  matlserg@mail.ru  2016-11-01            qip.ru
# 2  matlserg@mail.ru  2017-11-04    myheritage.com
# 3  matlserg@mail.ru  2016-10-21         adobe.com
# 4  matlserg@mail.ru  2021-02-04      rzd-bonus.ru
#
#                                                 desc
# 0  Big data e-mail verification platform verifica...
# 1  In 2011, Russian instant messaging service pro...
# 2  In October 2017, a customer database belonging...
# 3  In October of 2013, criminals penetrated Adobe...
# 4  In June 2020, the Russian Railways Bonus Progr...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)
# ```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: `<дата поста> - <текст поста>`

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий [GitHub](https://github.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
